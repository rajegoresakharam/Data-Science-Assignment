# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
house = pd.read_csv('../Datasets/kc_house_data.csv')

# %%
house.info()

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## #Data Visualization and Data Analysis

# %%
#scatterplot
plt.figure(figsize=(4,4),dpi=200)
sns.scatterplot(data=house,x='price',y='sqft_living',alpha=0.2)
# Out:
# <AxesSubplot:xlabel='price', ylabel='sqft_living'>

# %%
sns.countplot(data=house,x='bedrooms')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(data=house,x='bathrooms')
plt.xticks(rotation=90);

# %%
sns.barplot(data=house,x='sqft_living',y='bedrooms')
plt.xticks(rotation=90);
plt.xlim(0,10)
# Out:
# (0.0, 10.0)

# %%
sns.scatterplot(data=house,x='price',y='floors')
# Out:
# <AxesSubplot:xlabel='price', ylabel='floors'>

# %%
sns.scatterplot(data=house,x='price',y='long',hue='floors')
# Out:
# <AxesSubplot:xlabel='price', ylabel='long'>

# %%
sns.boxplot(data=house,y='price')
# Out:
# <AxesSubplot:ylabel='price'>

# %%
plt.figure(figsize=(6,4),dpi=200)
sns.scatterplot(data=house,x='sqft_living15',y='sqft_lot15',hue='zipcode',palette='viridis',alpha=0.7)
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='sqft_lot15'>

# %%
sns.countplot(data=house,x='grade')
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df = house[['price','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grade','sqft_above','sqft_basement'
           ,'yr_built','yr_renovated','lat','long','sqft_living15','sqft_lot15']]

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
corr_ = df.corr()['price'].sort_values()

# %%
corr_
# Out:
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308350
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525138
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %%
#correlation plot
sns.barplot(y=corr_[:-1],x=corr_[:-1].index)
plt.xticks(rotation=90);

# %% [markdown]
# ## Feature Selection

# %%
X = df[['floors','waterfront','lat','bedrooms','sqft_basement','view','bathrooms','sqft_living15','sqft_above','grade','sqft_living']]
y = df['price']

# %% [markdown]
# # #train-test-split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=101,test_size=0.3)

# %% [markdown]
# # #feature Standardlization

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X_train_scalr = std.fit_transform(X_train)
X_test_sclar = std.transform(X_test)

# %% [markdown]
# # #LogesticRegression model build

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train_scalr,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_sclar)

# %% [markdown]
# # #Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 46374804279.50554

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 135054.14607063326

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6694005579746066

# %%
#help(LinearRegression)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_model = PolynomialFeatures()

# %%
X_feature = poly_model.fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_feature,y,random_state=101,test_size=0.3)

# %%
X_train_Sclar = std.fit_transform(X_train)
X_test_Sclar = std.transform(X_test)

# %%
model.fit(X_train_Sclar,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_Sclar)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7512644171998701

# %%
# #Best Degree value(K)
r2_Score = []
for k in range(1,10):
    poly_model = PolynomialFeatures(degree=k,include_bias=False)
    X_feature = poly_model.fit_transform(X)
    X_train,X_test,y_train,y_test = train_test_split(X_feature,y,random_state=101,test_size=0.3)
    X_train_Sclar = std.fit_transform(X_train)
    X_test_Sclar = std.transform(X_test)
    model.fit(X_train_Sclar,y_train)
    y_pred = model.predict(X_test_Sclar)
    r2_Score.append(r2_score(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 3>()
#       2 r2_Score = []
#       3 for k in range(1,10):
# ----> 4     poly_model = PolynomialFeatures(degree=k,include_bias=False)
#       5     X_feature = poly_model.fit_transform(X)
#       6     X_train,X_test,y_train,y_test = train_test_split(X_feature,y,random_state=101,test_size=0.3)
#
# NameError: name 'PolynomialFeatures' is not defined

# %%
r2_Score
