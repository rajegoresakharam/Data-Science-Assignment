# %% [markdown]
# #### Create the classes and functions as per following description:
# - Create a class Person :
#    - The attributes of the class are name, age, city
#    - The functions of the class are :
#        - __init__(self, name, age, city)
#        - show_details(self)
#        - update_city(self, new_city)
#
# - Create a class Employee which inherits the class Person:
#     - The attributes of the class are name , age, city, salary, position, dept
#     - The functions of the class are :
#         - __init__(self, name , age, city, salary, position, dept)
#         - show_details(self)
#         - update_salary(self, new_salary)
#         - update_dept(self, new_dept)
#         - update_position(self, new_pos)
#         - inc_salary(self)
#         - dec_salary
#
# - Make use of the super function when necessary
# - Create objects and Demonstrate working of all the functions

# %%
class Employee(Person):
    salary=None
    position=None
    dept=None
    def __init__(self,name,age,city,salary,position,dept):
        Person.__init__(self,name,age,city)
        self.salary=salary
        self.position=position
        self.dept=dept
        
    def show_details(self):
        print("Name:-",self.name)
        print("Age:-",self.age)
        print("City:-",self.city)
        print("Salary:-",self.salary)
        print("Position:-",self.position)
        print("Dept:-",self.dept)
        
    def update_salary(self,salary):
        self.salary=salary
    def update_dept(self,dept):
        self.dept=dept
    def update_position(self,new_pos):
        self.position=new_pos
    def inc_salary(self,amount):
        self.salary +=amount
    def dec_salary(self,dec):
        self.salary -=dec
        
salary=int(input("Enter the salary of employee:- "))
position=input("Enter the postion of Employee in the org.:- ")
dept=input("Enter the dept of the employee:- ")

emp=Employee(name,age,city,salary,position,dept)
print("**********************************************Employee Details*************************************************")
emp.show_details()

yes=input("Do you want to update salary details(Y?N):- ")
if yes=='Y':
    new_salary=int(input("Enter the new salary:- "))
    emp.update_salary(new_salary)
    print("**********************************************Employee Details After Update*************************************************")
    emp.show_details()
    
    
yes=input("Do you want to update dept details(Y?N):- ")
if yes=='Y':
    new_dept=(input("Enter the new Dept:- "))
    emp.update_dept(new_dept)
    print("**********************************************Employee Details After Update*************************************************")
    emp.show_details() 
    
yes=input("Do you want to update position details(Y?N):- ")
if yes=='Y':
    new_position=(input("Enter the new position:- "))
    emp.update_position(new_position)
    print("**********************************************Employee Details After Update*************************************************")
    emp.show_details()
    
    
    
    
    
yes=input("Do you want to Increase salary details(Y?N):- ")
if yes=='Y':
    Inc_salary=int(input("Enter the new salary:- "))
    emp.inc_salary(Inc_salary)
    print("**********************************************Employee Details After Update*************************************************")
    emp.show_details()
    
    
    
yes=input("Do you want to Decrease salary (Y?N):- ")
if yes=='Y':
    Dec_salary=int(input("Enter the Decrease salary:- "))
    emp.dec_salary(new_salary)
    print("**********************************************Employee Details After Update*************************************************")
    emp.show_details()
    
    
    
print("*******************************************************Thank You!**********************************************************")
# Out:
# Enter the salary of employee:- 30000
# Enter the postion of Employee in the org.:- TCS
# Enter the dept of the employee:- BigData
# **********************************************Employee Details*************************************************
# Name:- patil
# Age:- 42
# City:- pune
# Salary:- 30000
# Position:- TCS
# Dept:- BigData
# Do you want to update salary details(Y?N):- Y
# Enter the new salary:- 35000
# **********************************************Employee Details After Update*************************************************
# Name:- patil
# Age:- 42
# City:- pune
# Salary:- 35000
# Position:- TCS
# Dept:- BigData
# Do you want to update dept details(Y?N):- Y
# Enter the new Dept:- Data Science
# **********************************************Employee Details After Update*************************************************
# Name:- patil
# Age:- 42
# City:- pune
# Salary:- 35000
# Position:- TCS
# Dept:- Data Science
# Do you want to update position details(Y?N):- Y
# ...

# %%
class Person:
    name=None
    age=None
    city=None
    def __init__(self,name,age,city):
        self.name=name
        self.age=age
        self.city=city
    def show_details(self):
        print(self.name)
        print(self.age)
        print(self.city)
    
    def update_city(self,city):
        self.city=city
        
        
name=input("Enter the name:- ")
age=int(input("Ennter your Age:- "))
city=input("Enter your city:-")

p = Person(name,age,city)
p.show_details()


yes=input("Do you want to update City:- (Y?N)")
if yes=='Y':
    updatedname=input("Enter city Name:- ")
    p.update_city(updatedname)
    print("Now the updated records are as follows........!")
    p.show_details()
else:
    pass
# Out:
# Enter the name:- patil
# Ennter your Age:- 42
# Enter your city:-pune
# patil
# 42
# pune
# Do you want to update City:- (Y?N)Y
# Enter city Name:- nanded
# Now the updated records are as follows........!
# patil
# 42
# nanded
